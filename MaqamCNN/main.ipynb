# %%
# !python main.py --gpus 0
# Out:
# gpu available : True
# gpu devices being used:  [0]
# dataset mode:  train
# Start training!!
# solver mode :  train
# dataset mode:  train
# solver mode :  train
# dataset mode:  train
# Epoch [1/50], Iter [10/320] loss : 0.5168
# Retrieval : AROC = 0.635, AP = 0.441 /  Annotation : AROC = 0.667, AP = 0.635
# Epoch [1/50], Iter [20/320] loss : 0.4940
# Retrieval : AROC = 0.807, AP = 0.669 /  Annotation : AROC = 0.688, AP = 0.667
# Epoch [1/50], Iter [30/320] loss : 0.5380
# Retrieval : AROC = 0.693, AP = 0.477 /  Annotation : AROC = 0.625, AP = 0.573
# Epoch [1/50], Iter [40/320] loss : 0.6148
# Retrieval : AROC = 0.559, AP = 0.425 /  Annotation : AROC = 0.542, AP = 0.568
# Epoch [1/50], Iter [50/320] loss : 0.5844
# Retrieval : AROC = 0.545, AP = 0.504 /  Annotation : AROC = 0.583, AP = 0.583
# Epoch [1/50], Iter [60/320] loss : 0.5321
# Retrieval : AROC = 0.685, AP = 0.518 /  Annotation : AROC = 0.604, AP = 0.630
# Epoch [1/50], Iter [70/320] loss : 0.4814
# ...
